# %% [markdown]
# <a href="https://colab.research.google.com/github/sakshi-1208/python_for_Datascience/blob/main/helloworld.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("hello world")
# Out:
# hello world

# %%
print("My name is sakshi")
print("My age is 24")
# Out:
# My name is sakshi
# My age is 24

# %%
print("My name is Sakshi", "My age is 24")
# Out:
# My name is Sakshi My age is 24

# %%
print(25)
print(34+26)
print(23-26)
# Out:
# 25
# 60
# -3

# %%
name="Sakshi"
age=25
price=25.99

print(name, age)
print(price)
# Out:
# Sakshi 25
# 25.99
