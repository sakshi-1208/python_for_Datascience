# %% [markdown]
# <a href="https://colab.research.google.com/github/sakshi-1208/python_for_Datascience/blob/main/stringfunctions.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#string

str1 = "this is a String"
Str2 = 'Sakshi'
Str3 = """this is apna college's tutorial"""

str4 = "This is a string \n we are creating it in python"
print(str4)

print(str1 + Str2) #concatenation

print(len(str3))
# Out:
# This is a string
#  we are creating it in python
# this is a StringSakshi
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-3761950970.py in <cell line: 0>()
#      10 print(str1 + Str2) #concatenation
#      11
# ---> 12 print(len(str3))
#      13
#
# NameError: name 'str3' is not defined

# %%
str = "i from am studying python from apnacollege"
print(str.endswith("ege"))
print(str.endswith("app"))
# Out:
# True
# False

# %%
print(str.capitalize())
# Out:
# I am studying python from apna college

# %%
print(str.replace("o", "a"))
print(str.replace("python", "Java"))
# Out:
# i am studying pythan fram apnacallege
# i am studying Java from apnacollege

# %%
print(str.find("o"))
print(str.find("from"))
print(str.find("Q"))
# Out:
# 18
# 21
# -1

# %%
print(str.count("o"))
print(str.count("from"))
# Out:
# 4
# 2

# %%
#WAP to input user's first name and print its length

name = input("enter the first name: ")
print("Length of your name is: ", len(name))
# Out:
# enter the first name: sakshi
# Length of your name is:  6

# %%
# WAP to find the occurrence of "$" in a String

str1 = "$akshi i$ great."
print(str1.count("$"))
# Out:
# 2
