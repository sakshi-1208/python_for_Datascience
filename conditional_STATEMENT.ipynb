# %% [markdown]
# <a href="https://colab.research.google.com/github/sakshi-1208/python_for_Datascience/blob/hello-world/conditional_STATEMENT.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
age = int(input("enter the age: "))
if(age>=18):
  print("can vote and apply for license") #indentation
else:
  print("SORRY, cannot apply for license")
# Out:
# enter the age: 18
# can vote and apply for license

# %%
light = input("enter red, yellow, green: ")

if(light == "red"):
  print("STOP")
elif(light == "green"):
  print("GO")
elif(light == "yellow"):
  print("look")
else:
  print("error")
# Out:
# enter red, yellow, green: yellow
# look

# %%
num = 10
if(num>4):
  print("greater than 4")
if(num>7):
  print("greater than 7")
# Out:
# greater than 4
# greater than 7

# %%
# students grade

marks = int(input("enter the marks of student: "))

if(marks>=90):
  grade = "A"
elif(marks<90 and marks>=80):
  grade = "B"
elif(marks<80 and marks>=70):
  grade = "C"
else:
  grade = "D"

print("grade of the student is: ", grade)
# Out:
# enter the marks of student: 67
# grade of the student is:  D

# %%
#nesting(if k andr if likhna)

age = int(input("enter the age: "))
if(age>=18):
  if(age>=80):
    print("cannot vote and apply for license") #indentation
  else:
    print("can drive")
else:
  print("SORRY, cannot apply for license")
# Out:
# enter the age: 90
# cannot vote and apply for license

# %%
#WAP to check if a number entered by the user is odd or even

number=int(input("enter the number: "))
if(number%2==0):
  print("even")
else:
  print("odd")
# Out:
# enter the number: 300001
# odd

# %%
#WAP to find the greatest of 3 numbers entered by the user

num1= int(input("enter the first number: "))
num2= int(input("enter the second number: "))
num3= int(input("enter the third number: "))

if(num1>num2 and num1>num3):
  print(num1, " is greater than ", num2, "and ", num3)
elif(num2>num1 and num2>num3):
  print(num2, " is greater than ", num1, "and ", num3)
else:
  print(num3, " is greater than ", num1, "and ", num2)
# Out:
# enter the first number: 3
# enter the second number: 2
# enter the third number: 1
# 3  is greater than  2 and  1

# %%
#WAP to check if a number is multiple of 7 or not

number=int(input("enter the number: "))
if(number%7==0):
  print("multiple of 7")
else:
  print("not multiple of 7")
# Out:
# enter the number: 30
# not multiple of 7
